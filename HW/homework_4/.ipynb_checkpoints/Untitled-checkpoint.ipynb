# %%
import pandas as pd
import matplotlib.pyplot as plt#
import seaborn as sns
from matplotlib.colors import ListedColormap

from sklearn.model_selection import cross_val_score, cross_validate, train_test_split
from sklearn.linear_model import LogisticRegression
import sklearn.metrics as sm

# %%
sample= pd.read_csv('sample_submission.csv')
train= pd.read_csv('train.csv')
test= pd.read_csv('test.csv')
#df = pd.read_csv('train.csv')

# %%
train.tail()
# Out:
#      PassengerId  Pclass                                          Name  \
# 845          756       2                     Hamalainen, Master. Viljo
# 846         1297       2  Nourney, Mr. Alfred (Baron von Drachstedt")"
# 847          531       2                      Quick, Miss. Phyllis May
# 848          721       2             Harper, Miss. Annie Jessie "Nina"
# 849         1022       3                       Spinner, Mr. Henry John
#
#         Sex    Age  SibSp  Parch           Ticket     Fare Cabin Embarked  \
# 845    male   0.67      1      1           250649  14.5000   NaN        S
# 846    male  20.00      0      0    SC/PARIS 2166  13.8625   D38        C
# 847  female   2.00      1      1            26360  26.0000   NaN        S
# 848  female   6.00      0      1           248727  33.0000   NaN        S
# 849    male  32.00      0      0  STON/OQ. 369943   8.0500   NaN        S
#
#      Survived
# 845         1
# 846         1
# 847         1
# 848         1
# 849         0

# %%
train.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   850.000000  850.000000  686.000000  850.000000  850.000000
# mean    656.848235    2.295294   29.850583    0.470588    0.368235
# std     371.701600    0.832837   14.141324    0.954664    0.865340
# min       1.000000    1.000000    0.330000    0.000000    0.000000
# 25%     340.750000    2.000000   21.000000    0.000000    0.000000
# 50%     657.000000    3.000000   28.000000    0.000000    0.000000
# 75%     969.750000    3.000000   38.000000    1.000000    0.000000
# max    1308.000000    3.000000   80.000000    8.000000    9.000000
#
#              Fare    Survived
# count  849.000000  850.000000
# mean    33.507121    0.382353
# std     53.553686    0.486248
# min      0.000000    0.000000
# 25%      7.895800    0.000000
# 50%     14.400000    0.000000
# 75%     30.500000    1.000000
# max    512.329200    1.000000

# %%
train.describe(include=['object'])
# Out:
#                     Name   Sex  Ticket        Cabin Embarked
# count                850   850     850          182      850
# unique               849     2     664          138        3
# top     Kelly, Mr. James  male  347077  C23 C25 C27        S
# freq                   2   554       6            5      595

# %%
train.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Survived         int64
# dtype: object

# %%
colors = ListedColormap(["blue", "red", "green"])

train.Survived
# plt.figure(figsize=(10,7))
# plt.title("Dataset visualization")
# plt.scatter(blobs[0][:,0], blobs[0][:,1], c=df.Survived, cmap=colors, s=50)
# plt.show()
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 845    1
# 846    1
# 847    1
# 848    1
# 849    0
# Name: Survived, Length: 850, dtype: int64

# %%
train['Survived'].value_counts()

sns.countplot(x='Survived',data=df,palette='hls')
plt.show()

# %%
train.groupby('Survived').mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          676.645714  2.502857  30.144450  0.474286  0.310476  23.015760
# 1          624.867692  1.960000  29.416679  0.464615  0.461538  50.422423

# %%
train.groupby('Pclass').mean()
# Out:
#         PassengerId        Age     SibSp     Parch       Fare  Survived
# Pclass
# 1        661.097087  39.237268  0.422330  0.349515  90.501538  0.635922
# 2        664.983957  29.527600  0.406417  0.352941  20.820699  0.406417
# 3        651.603939  24.785823  0.518600  0.382932  12.962189  0.258206

# %%
train.groupby('Embarked').mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare  \
# Embarked
# C          685.088235  1.870588  32.585182  0.358824  0.352941  63.263042
# Q          661.211765  2.964706  26.109375  0.364706  0.070588  10.478973
# S          648.156303  2.321008  29.357505  0.517647  0.415126  28.286391
#
#           Survived
# Embarked
# C         0.541176
# Q         0.329412
# S         0.344538

# %%
train.groupby('Sex').mean()
# Out:
#         PassengerId    Pclass        Age     SibSp     Parch       Fare  \
# Sex
# female   622.121622  2.131757  29.349190  0.587838  0.597973  46.477760
# male     675.402527  2.382671  30.132688  0.407942  0.245487  26.564428
#
#         Survived
# Sex
# female  0.746622
# male    0.187726

# %%
train.Cabin[df.Cabin.isna()==False].size
# Out:
# 182

# %%
train.groupby('Ticket').mean()
# Out:
#              PassengerId  Pclass        Age     SibSp     Parch    Fare  \
# Ticket
# 110152        507.666667     1.0  26.333333  0.000000  0.000000  86.500
# 110413        572.500000     1.0  28.500000  0.500000  1.500000  79.650
# 110489       1050.000000     1.0  42.000000  0.000000  0.000000  26.550
# 110564        431.000000     1.0  28.000000  0.000000  0.000000  26.550
# 110813        747.500000     1.0  62.000000  1.000000  0.000000  75.250
# ...                  ...     ...        ...       ...       ...     ...
# W./C. 14266  1114.000000     2.0  22.000000  0.000000  0.000000  10.500
# W./C. 6607    948.333333     3.0        NaN  1.000000  2.000000  23.450
# W./C. 6608    431.333333     3.0  14.333333  1.666667  2.333333  34.375
# W.E.P. 5734   499.500000     1.0  46.500000  1.000000  0.000000  61.175
# WE/P 5735     541.000000     1.0  36.000000  0.000000  2.000000  71.000
#
#              Survived
# Ticket
# 110152            1.0
# 110413            1.0
# 110489            0.0
# 110564            1.0
# 110813            0.5
# ...               ...
# W./C. 14266       1.0
# W./C. 6607        0.0
# W./C. 6608        0.0
# W.E.P. 5734       0.5
# WE/P 5735         1.0
#
# [664 rows x 7 columns]

# %%
cols = train.columns
train_columns = cols[1:-2]
target_columns = cols[-1]
###
train_columns = ['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']
train.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          888       1                  Graham, Miss. Margaret Edith  female
# 1         1249       3                           Lockyer, Mr. Edward    male
# 2         1240       2                              Giles, Mr. Ralph    male
# 3          221       3                Sunderland, Mr. Victor Francis    male
# 4         1105       2  Howard, Mrs. Benjamin (Ellen Truelove Arman)  female
#
#     Age  SibSp  Parch           Ticket     Fare Cabin Embarked  Survived
# 0  19.0      0      0           112053  30.0000   B42        S         1
# 1   NaN      0      0             1222   7.8792   NaN        S         0
# 2  24.0      0      0           248726  13.5000   NaN        S         0
# 3  16.0      0      0  SOTON/OQ 392089   8.0500   NaN        S         1
# 4  60.0      1      0            24065  26.0000   NaN        S         0

# %%
sex_map = {'male' : 0, 'female': 1}
emb_map = {'C':0, 'Q':1,'S':2}
train['Sex'] = train['Sex'].map(sex_map)
train['Embarked'] = train['Embarked'].map(emb_map)
train.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          888       1                  Graham, Miss. Margaret Edith    1
# 1         1249       3                           Lockyer, Mr. Edward    0
# 2         1240       2                              Giles, Mr. Ralph    0
# 3          221       3                Sunderland, Mr. Victor Francis    0
# 4         1105       2  Howard, Mrs. Benjamin (Ellen Truelove Arman)    1
#
#     Age  SibSp  Parch           Ticket     Fare Cabin  Embarked  Survived
# 0  19.0      0      0           112053  30.0000   B42         2         1
# 1   NaN      0      0             1222   7.8792   NaN         2         0
# 2  24.0      0      0           248726  13.5000   NaN         2         0
# 3  16.0      0      0  SOTON/OQ 392089   8.0500   NaN         2         1
# 4  60.0      1      0            24065  26.0000   NaN         2         0

# %%
train_first = train[train_columns]#.dropna()
target_first = train[target_columns]
target_first = target_first[train_first.index]

# %%
#train_first_scaled = (train_first - train_first.min(axis=0))/(train_first.max(axis=0) - train_first.min(axis=0))
train_first_scaled = (train_first - train_first.mean(axis=0))/train_first.std(axis=0)
train_first_scaled[train_first_scaled['Fare'].isnull()]
# Out:
#       Pclass       Sex     SibSp     Parch  Fare  Embarked
# 17  0.846151 -0.730525 -0.492936 -0.425538   NaN  0.619809

# %%
X_train, X_test, y_train, y_test = train_test_split(train_first_scaled, target_first, test_size=0.2, random_state=42)

# %%
logreg_model = LogisticRegression()
logreg_model.fit(X_train, y_train)
# Out:
# c:\users\артём\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-371-a12b3e6735f6> in <module>
#       1 logreg_model = LogisticRegression()
# ----> 2 logreg_model.fit(X_train, y_train)
#
# c:\users\артём\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1530
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1532                          accept_large_sparse=solver != 'liblinear')
#    1533         check_classification_targets(y)
#    1534         self.classes_ = np.unique(y)
#
# c:\users\артём\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# c:\users\артём\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# c:\users\артём\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
vars(logreg_model)
# Out:
# {'penalty': 'l2',
#  'dual': False,
#  'tol': 0.0001,
#  'C': 1.0,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'class_weight': None,
#  'random_state': None,
#  'solver': 'warn',
#  'max_iter': 100,
#  'multi_class': 'warn',
#  'verbose': 0,
#  'warm_start': False,
#  'n_jobs': None,
#  'l1_ratio': None,
#  'classes_': array([0, 1], dtype=int64),
#  'coef_': array([[-0.75994221,  1.1935032 , -0.40923023, -0.21613402,  0.04160011,
#           0.075388  , -0.21655749]]),
#  'intercept_': array([-0.52813776]),
#  'n_iter_': array([4], dtype=int32)}

# %%
preds = logreg_model.predict(X_test)

# %%
sm.accuracy_score(y_test, preds)
# Out:
# 0.7883211678832117

# %%
sm.precision_score(y_test, preds)
# Out:
# 0.7959183673469388

# %%
sm.recall_score(y_test, preds)
# Out:
# 0.6724137931034483

# %%
test_first = test[train_columns].copy()

test_first['Sex'] = test_first['Sex'].map(sex_map)
test_first['Embarked'] = test_first['Embarked'].map(emb_map)
test_first['Age'].fillna(test_first['Age'].mean(), inplace=True)
test_first_scaled = (test_first - test_first.mean(axis=0))/test_first.std(axis=0)
#для возраста используем минимаксную нормализацию
test_first_scaled['Age'] = (test_first['Age'] - test_first['Age'].min())/(test_first['Age'].max() - test_first['Age'].min())
#test_first_scaled[test_first_scaled.isna()]
test[test['Age'].isnull()]
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 3            864       3        Sage, Miss. Dorothy Edith "Dolly"  female
# 9            613       3              Murphy, Miss. Margaret Jane  female
# 16            47       3                        Lennon, Mr. Denis    male
# 23           365       3                      O'Brien, Mr. Thomas    male
# 24           840       1                     Marechal, Mr. Pierre    male
# ..           ...     ...                                      ...     ...
# 423          181       3             Sage, Miss. Constance Gladys  female
# 429          230       3                  Lefebre, Miss. Mathilde  female
# 430          385       3                   Plotcharsky, Mr. Vasil    male
# 439         1091       3  Rasmussen, Mrs. (Lena Jacobsen Solvang)  female
# 447         1166       3                    Saade, Mr. Jean Nassr    male
#
#      Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 3    NaN      8      2  CA. 2343  69.5500   NaN        S
# 9    NaN      1      0    367230  15.5000   NaN        Q
# 16   NaN      1      0    370371  15.5000   NaN        Q
# 23   NaN      1      0    370365  15.5000   NaN        Q
# 24   NaN      0      0     11774  29.7000   C47        C
# ..   ...    ...    ...       ...      ...   ...      ...
# 423  NaN      8      2  CA. 2343  69.5500   NaN        S
# 429  NaN      3      1      4133  25.4667   NaN        S
# 430  NaN      0      0    349227   7.8958   NaN        S
# 439  NaN      0      0     65305   8.1125   NaN        S
# 447  NaN      0      0      2676   7.2250   NaN        C
#
# [99 rows x 11 columns]

# %%
preds = logreg_model.predict(test_first_scaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-331-3d6182a4b49b> in <module>
# ----> 1 preds = logreg_model.predict(test_first_scaled)
#
# c:\users\артём\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     287             Predicted class label per sample.
#     288         """
# --> 289         scores = self.decision_function(X)
#     290         if len(scores.shape) == 1:
#     291             indices = (scores > 0).astype(np.int)
#
# c:\users\артём\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     263                                  "yet" % {'name': type(self).__name__})
#     264
# --> 265         X = check_array(X, accept_sparse='csr')
#     266
#     267         n_features = self.coef_.shape[1]
#
# c:\users\артём\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# c:\users\артём\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
